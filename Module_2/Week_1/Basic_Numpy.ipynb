# %%
import numpy as np
import pandas as pd

# %%
def f_function(number):
    result = number ** 2 + 1
    return result

factorial_np = np.vectorize(f_function)
numbers = [1, 2, 3, 4]
numbers_array = np.array(numbers)
print(factorial_np(numbers_array))
# Out:
# [ 2  5 10 17]

# %%
# zeros function()
arr = np.zeros((2,3))
arr, arr.shape
# Out:
# (array([[0., 0., 0.],
#         [0., 0., 0.]]),
#  (2, 3))

# %%
# ones function()
arr = np.ones((2, 3))
print(arr)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
# full() function
arr = np.full((2, 3), 9)
print(arr)
# Out:
# [[9 9 9]
#  [9 9 9]]

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.random.random((2,3))
# Out:
# array([[0.85456984, 0.80935842, 0.14528484],
#        [0.64030408, 0.97622323, 0.89826686]])

# %%
# arange()
arr1 = np.arange(5)
print(arr1)

arr2 = np.arange(0, 5, 2)
print(arr2)
# Out:
# [0 1 2 3 4]
# [0 2 4]

# %% [markdown]
# Part One

# %%
arr = np.ones((3, 3)) > 0
arr
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True],
#        [ True,  True,  True]])

# %%
import numpy as np
arr1 = np . arange (10) . reshape (2 , -1)
arr2 = np . repeat (1 ,10) . reshape (2 , -1)
c = np . concatenate ([ arr1 , arr2 ] , axis =1)
print (" Result : \n", c )
# Out:
#  Result :
#  [[0 1 2 3 4 1 1 1 1 1]
#  [5 6 7 8 9 1 1 1 1 1]]

# %%
import numpy as np
arr = np . array ([1 ,2 ,3])
print ( np . repeat ( arr ,3) )
print ( np . tile ( arr ,3) )
# Out:
# [1 1 1 2 2 2 3 3 3]
# [1 2 3 1 2 3 1 2 3]

# %%
import numpy as np

a = np . array ([5 ,7 ,9 ,8 ,6 ,4 ,5])
b = np . array ([6 ,3 ,4 ,8 ,9 ,7 ,1])
print (" Result ", np . where (a <b , b , a ) )
# Out:
#  Result  [6 7 9 8 9 7 5]

# %% [markdown]
# Part Two

# %%
# %gdown 1i9dqan21DjQoG5Q_VEvm0LrVwAlXD0vB
# Out:
# UsageError: Line magic function `%gdown` not found.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread("./dog.jpeg")
img.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/vw/37t6_v416t9gjpbykjt9mfvw0000gn/T/ipykernel_94358/497875408.py in <cell line: 0>()
#       1 import matplotlib.image as mpimg
#       2 import matplotlib.pyplot as plt
# ----> 3 img = mpimg.imread("./dog.jpeg")
#       4 img.shape
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/image.py in imread(fname, format)
#    1523             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1524             )
# -> 1525     with img_open(fname) as image:
#    1526         return (_pil_png_to_float_array(image)
#    1527                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/PIL/Image.py in open(fp, mode, formats)
#    3275
#    3276     if filename:
# -> 3277         fp = builtins.open(filename, "rb")
#    3278         exclusive_fp = True
#    3279
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/haodo/Documents/AIO/AIO2024_exercises/Module_2/Week_1/dog.jpeg'
